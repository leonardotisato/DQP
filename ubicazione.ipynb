# %%
import pandas as pd
import numpy as np
import re
DATASET = pd.read_csv('Comune-di-Milano-Servizi-alla-persona-parrucchieri-estetisti(in).csv',sep=';',encoding='unicode_escape')
DATASET = DATASET.fillna(pd.NA)
DATASET.head()
# Out:
#   Tipo esercizio pa                           Ubicazione Tipo via  \
# 0              <NA>     LGO DEI GELSOMINI N. 10 (z.d. 6)      LGO
# 1              <NA>              PZA FIDIA N. 3 (z.d. 9)      PZA
# 2              <NA>             VIA ADIGE N. 10 (z.d. 5)      VIA
# 3              <NA>  VIA BARACCHINI FLAVIO N. 9 (z.d. 1)      VIA
# 4              <NA>           VIA BERGAMO N. 12 (z.d. 4)      VIA
#
#                  Via Civico  Codice via ZD  \
# 0      DEI GELSOMINI     10      5394.0  6
# 1              FIDIA      3      1144.0  9
# 2              ADIGE     10      4216.0  5
# 3  BARACCHINI FLAVIO      9       356.0  1
# 4            BERGAMO     12      3189.0  4
#
#                                 Prevalente  Superficie altri usi  \
# 0                                     <NA>                   NaN
# 1  CENTRO MASSAGGI RILASSANTI NON ESTETICI                   2.0
# 2                         CENTRO BENESSERE                   2.0
# 3                    TRUCCO SEMIPERMANENTE                   NaN
# 4                                     <NA>                   NaN
#
#    Superficie lavorativa
# 0                   55.0
# 1                   28.0
# 2                   27.0
# 3                    NaN
# 4                   50.0

# %%
#Normalization for Ubicazione
DATASET['Ubicazione'] = DATASET['Ubicazione'].str.replace('num', 'N')
DATASET['Ubicazione'] = DATASET['Ubicazione'].str.replace('n', 'N')

# %%
DATASET.drop(['Tipo esercizio pa', 'Prevalente', 'Superficie altri usi', 'Superficie lavorativa'], axis=1, inplace=True)
DATASET = DATASET[['Civico', 'ZD', 'Tipo via', 'Via', 'Codice via', 'Ubicazione']]

# Splitting the "Ubicazione" column on "N." to separate address and addition data
split_column = DATASET['Ubicazione'].str.split(r"\bN\.", n=1, expand=True)
split_column.columns = ['Ubicazione_effettiva', 'Ubicazione_data']

# Clean the Ubicazione_data by stripping leading/trailing whitespace
split_column['Ubicazione_data'] = split_column['Ubicazione_data'].str.strip()

# Add split columns to DATASET
DATASET = pd.concat([DATASET, split_column], axis=1)

# Splitting the "Ubicazione_data" column on "(" to separate civico and z.d.
split_column_2 = DATASET['Ubicazione_data'].str.split("(", n=1, expand=True)
split_column_2.columns = ['Civico_to_check', 'ZD_to_check']

# Add to original database
DATASET = pd.concat([DATASET, split_column_2], axis=1)

# Remove ";" from "Civico_to_check"
DATASET['Civico_to_check'] = DATASET['Civico_to_check'].str.replace(";", "", regex=False)
DATASET['Civico_to_check'] = DATASET['Civico_to_check'].str.strip()

# Remove the closing parenthesis ")" and the ZD description from the "ZD_to_check" column
DATASET["ZD_to_check"] = DATASET["ZD_to_check"].str.replace("z.d.", "", regex=False)
DATASET["ZD_to_check"] = DATASET["ZD_to_check"].str.replace(")", "", regex=False)
DATASET['ZD_to_check'] = DATASET['ZD_to_check'].str.strip()

# Convert null/empty values to pd.NA
DATASET['Civico_to_check'] = DATASET['Civico_to_check'].fillna(pd.NA)
DATASET['ZD_to_check'] = DATASET['ZD_to_check'].fillna(pd.NA)

# Splitting the "Ubicazione_effettiva" column on the first " " to separate "Tipo via" and "Via"
split_column_3 = DATASET['Ubicazione_effettiva'].str.split(" ", n=1, expand=True)
split_column_3.columns = ['Tipo via_to_check', 'Via_to_check']

# Add to original database
DATASET = pd.concat([DATASET, split_column_3], axis=1)

# Convert null/empty values to pd.NA for Tipo via and Via
DATASET['Tipo via_to_check'] = DATASET['Tipo via_to_check'].fillna(pd.NA)
DATASET['Tipo via_to_check'] = DATASET['Tipo via_to_check'].str.strip()
DATASET['Via_to_check'] = DATASET['Via_to_check'].fillna(pd.NA)
DATASET['Via_to_check'] = DATASET['Via_to_check'].str.strip()

DATASET = DATASET.drop(['Ubicazione_effettiva', 'Ubicazione_data'], axis=1)
dfvia = DATASET
DATASET
# Out:
#      Civico ZD Tipo via                Via  Codice via  \
# 0        10  6      LGO      DEI GELSOMINI      5394.0
# 1         3  9      PZA              FIDIA      1144.0
# 2        10  5      VIA              ADIGE      4216.0
# 3         9  1      VIA  BARACCHINI FLAVIO       356.0
# 4        12  4      VIA            BERGAMO      3189.0
# ...     ... ..      ...                ...         ...
# 3904      1  1      VIA   SARPI FRA' PAOLO      7210.0
# 3905      4  1      CSO  DI PORTA TICINESE       541.0
# 3906      2  9      VIA          CANDOGLIA      1518.0
# 3907   <NA>  1      VIA             NIRONE       640.0
# 3908     15  1      VIA          MADONNINA       134.0
#
#                                              Ubicazione  \
# 0                      LGO DEI GELSOMINI N. 10 (z.d. 6)
# 1                               PZA FIDIA N. 3 (z.d. 9)
# 2                              VIA ADIGE N. 10 (z.d. 5)
# 3                   VIA BARACCHINI FLAVIO N. 9 (z.d. 1)
# 4                            VIA BERGAMO N. 12 (z.d. 4)
# ...                                                 ...
# 3904  VIA SARPI FRA' PAOLO N. 1 coN iNgr.da v.le moN...
# 3905              CSO DI PORTA TICINESE N. 4 ; (z.d. 1)
# 3906                      VIA CANDOGLIA N. 2 ; (z.d. 9)
# 3907                        VIA NIRONE N.002a; (z.d. 1)
# 3908                     VIA MADONNINA N. 15 ; (z.d. 1)
#
#                       Civico_to_check ZD_to_check Tipo via_to_check  \
# 0                                  10           6               LGO
# 1                                   3           9               PZA
# 2                                  10           5               VIA
# 3                                   9           1               VIA
# 4                                  12           4               VIA
# ...                               ...         ...               ...
# 3904  1 coN iNgr.da v.le moNtello 4/6           1               VIA
# 3905                                4           1               CSO
# 3906                                2           9               VIA
# 3907                             002a           1               VIA
# 3908                               15           1               VIA
#
#            Via_to_check
# 0         DEI GELSOMINI
# 1                 FIDIA
# 2                 ADIGE
# 3     BARACCHINI FLAVIO
# 4               BERGAMO
# ...                 ...
# 3904   SARPI FRA' PAOLO
# 3905  DI PORTA TICINESE
# 3906          CANDOGLIA
# 3907             NIRONE
# 3908          MADONNINA
#
# [3909 rows x 10 columns]

# %% [markdown]
# ### Civico e ZD

# %%
# Check if the civico is equal to the civico_to_check, return only the rows where they are not equal
notok = DATASET[(DATASET['Civico'] != DATASET['Civico_to_check']) | (DATASET['ZD'] != DATASET['ZD_to_check'])]
notok
# Out:
#      Civico            ZD Tipo via                   Via  Codice via  \
# 20       23             3      VIA      STRAMBIO GAETANO      3168.0
# 32     <NA>          <NA>     <NA>                  <NA>         NaN
# 33     1111  ACCONCIATORE     COMO                    15         9.0
# 45        2             1      PAS                 DUOMO       102.0
# 92       17             6      VIA  DARWIN CARLO ROBERTO      5238.0
# ...     ...           ...      ...                   ...         ...
# 3890     48             6      VIA          GESSI ROMOLO      6121.0
# 3896      4             7      VIA         DURER ALBERTO      6602.0
# 3897     31             2      VIA    ZURETTI GIANFRANCO      1216.0
# 3904      1             1      VIA      SARPI FRA' PAOLO      7210.0
# 3907   <NA>             1      VIA                NIRONE       640.0
#
#                                              Ubicazione  \
# 20    VIA STRAMBIO GAETANO N. 23 estetista iN appart...
# 32                 CSO COMO N. 15 iNterNo club f. coNti
# 33                                                  CSO
# 45                 PAS DUOMO N. 2 piaNo primo; (z.d. 1)
# 92    VIA DARWIN CARLO ROBERTO N. 17 iNt. resideNze ...
# ...                                                 ...
# 3890  VIA GESSI ROMOLO N. 48 coN iNgresso v.fra' bar...
# 3896       VIA DURER ALBERTO N. 4 primo piaNo; (z.d. 7)
# 3897  VIA ZURETTI GIANFRANCO N. 31 al secoNdo piaNo ...
# 3904  VIA SARPI FRA' PAOLO N. 1 coN iNgr.da v.le moN...
# 3907                        VIA NIRONE N.002a; (z.d. 1)
#
#                         Civico_to_check      ZD_to_check Tipo via_to_check  \
# 20         23 estetista iN appartameNto                3               VIA
# 32             15 iNterNo club f. coNti             <NA>               CSO
# 33                                 <NA>             <NA>               CSO
# 45                        2 piaNo primo                1               PAS
# 92       17 iNt. resideNze aNNi azzurri  per aNziaNi ( 6               VIA
# ...                                 ...              ...               ...
# 3890  48 coN iNgresso v.fra' bartolomeo                6               VIA
# 3896                      4 primo piaNo                7               VIA
# 3897        31 al secoNdo piaNo scala a                2               VIA
# 3904    1 coN iNgr.da v.le moNtello 4/6                1               VIA
# 3907                               002a                1               VIA
#
#               Via_to_check
# 20        STRAMBIO GAETANO
# 32                    COMO
# 33                    <NA>
# 45                   DUOMO
# 92    DARWIN CARLO ROBERTO
# ...                    ...
# 3890          GESSI ROMOLO
# 3896         DURER ALBERTO
# 3897    ZURETTI GIANFRANCO
# 3904      SARPI FRA' PAOLO
# 3907                NIRONE
#
# [535 rows x 10 columns]

# %%
# Clean and convert Civico_to_check and ZD_to_check before comparison
def clean_numeric_string(value):
    if pd.isna(value):
        return pd.NA, pd.NA
    
    if isinstance(value, str):
        value_str = value.strip()
        if not value_str:
            return pd.NA, pd.NA
        
        # Check if value contains at least one digit, otherwise return pd.NA
        if not re.search(r'\d', value_str):
            return pd.NA, pd.NA
        
        # Split after the first number
        match = re.match(r'^(\d+(?:[a-zA-Z](?![a-zA-Z])|/\d*)?)\s*(.*)', value_str)
        
        if match:
            numeric_part = match.group(1)
            additional_part = match.group(2) if match.group(2) else pd.NA
        else:
            # Fallback: if no match, return pd.NA
            return pd.NA, value
        
        # Remove leading zeros but keep at least one digit, preserving suffixes like /2, a, b, etc.
        numeric_part = re.sub(r'^0+(?=\d)', '', numeric_part)
        if not numeric_part:
            numeric_part = "0"
        
        return numeric_part, additional_part
        
    elif isinstance(value, (int, float)):
        return str(int(value)), pd.NA
    
    return pd.NA, pd.NA

# Apply cleaning to Civico_to_check and save both parts
DATASET[['Civico_to_check', 'Civico_additional']] = DATASET['Civico_to_check'].apply(
    lambda x: pd.Series(clean_numeric_string(x))
)
DATASET[['ZD_to_check', 'ZD_additional']] = DATASET['ZD_to_check'].apply(
    lambda x: pd.Series(clean_numeric_string(x))
)

# Convert to string for comparison, replacing pd.NA with empty string
DATASET['Civico'] = DATASET['Civico'].astype(str).replace('<NA>', '0').replace('nan', '0')
DATASET['ZD'] = DATASET['ZD'].astype(str).replace('<NA>', '0').replace('nan', '0')
DATASET['Civico_to_check'] = DATASET['Civico_to_check'].astype(str).replace('<NA>', '0')
DATASET['ZD_to_check'] = DATASET['ZD_to_check'].astype(str).replace('<NA>', '0')

# Check the not right values
condition = ((DATASET['Civico_to_check'] != DATASET['Civico']) | (DATASET['ZD_to_check'] != DATASET['ZD']))
check = DATASET[condition][['Civico', 'Civico_to_check', 'Civico_additional', 'ZD', 'ZD_to_check', 'ZD_additional']]
check
# Out:
#      Civico Civico_to_check            Civico_additional            ZD  \
# 32        0              15        iNterNo club f. coNti             0
# 33     1111               0                         <NA>  ACCONCIATORE
# 92       17              17  iNt. resideNze aNNi azzurri             6
# 144   40945             6/2                         <NA>             5
# 210      72               8                         <NA>             4
# ...     ...             ...                          ...           ...
# 3767    157              43                         <NA>             6
# 3801      0             21a                         <NA>             8
# 3818     13             21a                         <NA>             5
# 3839      0             11d                         <NA>             6
# 3907      0              2a                         <NA>             1
#
#      ZD_to_check    ZD_additional
# 32             0             <NA>
# 33             0             <NA>
# 92             0  per aNziaNi ( 6
# 144            5             <NA>
# 210            4             <NA>
# ...          ...              ...
# 3767           6             <NA>
# 3801           8             <NA>
# 3818           5             <NA>
# 3839           6             <NA>
# 3907           1             <NA>
#
# [169 rows x 6 columns]

# %%
# If Civico_to_check is not null and is not equal to Civico, replace Civico with Civico_to_check
DATASET.loc[:, 'Civico'] = DATASET.apply(
    lambda row: row["Civico_to_check"] if row["Civico"] == 0 else 
                (row["Civico"] if row["Civico_to_check"] == 0 else 
                (row["Civico_to_check"] if row["Civico"] != row["Civico_to_check"] else row["Civico"])), axis=1)
# If ZD_to_check is not null and is not equal to ZD, replace ZD with ZD_to_check
DATASET.loc[:, 'ZD'] = DATASET.apply(
    lambda row: row["ZD_to_check"] if row["ZD"] == 0 else 
                (row["ZD"] if row["ZD_to_check"] == 0 else 
                (row["ZD_to_check"] if row["ZD"] != row["ZD_to_check"] else row["ZD"])), axis=1)

DATASET.iloc[check.index]
# Out:
#      Civico ZD Tipo via                   Via  Codice via  \
# 32       15  0     <NA>                  <NA>         NaN
# 33        0  0     COMO                    15         9.0
# 92       17  0      VIA  DARWIN CARLO ROBERTO      5238.0
# 144     6/2  5      VIA                 PAVIA      5262.0
# 210       8  4      CSO                  LODI      4068.0
# ...     ... ..      ...                   ...         ...
# 3767     43  6      VIA           LORENTEGGIO      5132.0
# 3801    21a  8      VLE               CERTOSA      7174.0
# 3818    21a  5      VIA     LAGRANGE GIUSEPPE      5205.0
# 3839    11d  6      VIA                  BARI      5218.0
# 3907     2a  1      VIA                NIRONE       640.0
#
#                                              Ubicazione Civico_to_check  \
# 32                 CSO COMO N. 15 iNterNo club f. coNti              15
# 33                                                  CSO               0
# 92    VIA DARWIN CARLO ROBERTO N. 17 iNt. resideNze ...              17
# 144                           VIA PAVIA N. 6/2 (z.d. 5)             6/2
# 210                         codvia 4386 N.008; (z.d. 4)               8
# ...                                                 ...             ...
# 3767                  VIA SOLARI ANDREA N.043; (z.d. 6)              43
# 3801      VLE CERTOSA iNterNo palestra N.021a; (z.d. 8)             21a
# 3818                      VLE SABOTINO N.021a; (z.d. 5)             21a
# 3839                          VIA BARI N.011d; (z.d. 6)             11d
# 3907                        VIA NIRONE N.002a; (z.d. 1)              2a
#
#      ZD_to_check Tipo via_to_check              Via_to_check  \
# 32             0               CSO                      COMO
# 33             0               CSO                      <NA>
# 92             0               VIA      DARWIN CARLO ROBERTO
# 144            5               VIA                     PAVIA
# 210            4            codvia                      4386
# ...          ...               ...                       ...
# 3767           6               VIA             SOLARI ANDREA
# 3801           8               VLE  CERTOSA iNterNo palestra
# 3818           5               VLE                  SABOTINO
# 3839           6               VIA                      BARI
# 3907           1               VIA                    NIRONE
#
#                 Civico_additional    ZD_additional
# 32          iNterNo club f. coNti             <NA>
# 33                           <NA>             <NA>
# 92    iNt. resideNze aNNi azzurri  per aNziaNi ( 6
# 144                          <NA>             <NA>
# 210                          <NA>             <NA>
# ...                           ...              ...
# 3767                         <NA>             <NA>
# 3801                         <NA>             <NA>
# 3818                         <NA>             <NA>
# 3839                         <NA>             <NA>
# 3907                         <NA>             <NA>
#
# [169 rows x 12 columns]

# %%
#Check all the rows with again different values
condition = ((DATASET['Civico_to_check'] != DATASET['Civico']) | (DATASET['ZD_to_check'] != DATASET['ZD']))
check = DATASET[condition]
check
# Out:
# Empty DataFrame
# Columns: [Civico, ZD, Tipo via, Via, Codice via, Ubicazione, Civico_to_check, ZD_to_check, Tipo via_to_check, Via_to_check, Civico_additional, ZD_additional]
# Index: []

# %% [markdown]
# ### Tipo Via

# %%
dfvia = dfvia.drop(['Civico_to_check', 'ZD_to_check', 'Civico_additional', 'ZD_additional'], axis=1)
dfvia
# Out:
#      Civico ZD Tipo via                Via  Codice via  \
# 0        10  6      LGO      DEI GELSOMINI      5394.0
# 1         3  9      PZA              FIDIA      1144.0
# 2        10  5      VIA              ADIGE      4216.0
# 3         9  1      VIA  BARACCHINI FLAVIO       356.0
# 4        12  4      VIA            BERGAMO      3189.0
# ...     ... ..      ...                ...         ...
# 3904      1  1      VIA   SARPI FRA' PAOLO      7210.0
# 3905      4  1      CSO  DI PORTA TICINESE       541.0
# 3906      2  9      VIA          CANDOGLIA      1518.0
# 3907     2a  1      VIA             NIRONE       640.0
# 3908     15  1      VIA          MADONNINA       134.0
#
#                                              Ubicazione Tipo via_to_check  \
# 0                      LGO DEI GELSOMINI N. 10 (z.d. 6)               LGO
# 1                               PZA FIDIA N. 3 (z.d. 9)               PZA
# 2                              VIA ADIGE N. 10 (z.d. 5)               VIA
# 3                   VIA BARACCHINI FLAVIO N. 9 (z.d. 1)               VIA
# 4                            VIA BERGAMO N. 12 (z.d. 4)               VIA
# ...                                                 ...               ...
# 3904  VIA SARPI FRA' PAOLO N. 1 coN iNgr.da v.le moN...               VIA
# 3905              CSO DI PORTA TICINESE N. 4 ; (z.d. 1)               CSO
# 3906                      VIA CANDOGLIA N. 2 ; (z.d. 9)               VIA
# 3907                        VIA NIRONE N.002a; (z.d. 1)               VIA
# 3908                     VIA MADONNINA N. 15 ; (z.d. 1)               VIA
#
#            Via_to_check
# 0         DEI GELSOMINI
# 1                 FIDIA
# 2                 ADIGE
# 3     BARACCHINI FLAVIO
# 4               BERGAMO
# ...                 ...
# 3904   SARPI FRA' PAOLO
# 3905  DI PORTA TICINESE
# 3906          CANDOGLIA
# 3907             NIRONE
# 3908          MADONNINA
#
# [3909 rows x 8 columns]

# %%
# Check if there are some differences between Tipo via and Tipo via_to_check, Via and Via_to_check
condition = (
    (dfvia['Tipo via'].fillna(' ') != dfvia['Tipo via_to_check'].fillna(' ')) 
)
check = dfvia[condition]
check
# Out:
#      Civico ZD Tipo via                     Via  Codice via  \
# 32       15  0     <NA>                    <NA>         NaN
# 33        0  0     COMO                      15         9.0
# 210       8  4      CSO                    LODI      4068.0
# 243       0  1      CSO                SEMPIONE      7137.0
# 651      2a  6      PZA         FRATTINI PIETRO      5389.0
# 744     509  4      VIA                  MINCIO      4157.0
# 745     505  4      VIA             TAGLIAMENTO      4147.0
# 808     51a  1      VLE        CRISPI FRANCESCO      1063.0
# 1203    192  8      VIA       RUGGERO DI LAURIA      7163.0
# 1633    55a  2      PZA        QUATTRO NOVEMBRE      1199.0
# 1775    19e  6      PZA  BAZZI GIOVANNI ANTONIO      6102.0
# 2221   1773  2      VIA             OXILIA NINO      2287.0
# 2223    353  2      VIA                  PADOVA      2275.0
# 2413      0  3      VIA       MALPIGHI MARCELLO      2182.0
# 2844    99c  9      PZA            SAN GIUSEPPE      1442.0
# 3042     33  7      VLE   SAN MICHELE DEL CARSO      6212.0
# 3114    562  3      VIA         PACINI GIOVANNI      2571.0
# 3275    102  9      VLE        SUZZANI GIOVANNI      1446.0
# 3529   3032  1      VIA          CANONICA LUIGI      7121.0
# 3534     83  1      VIA       S. GIOV. SUL MURO       609.0
# 3699   3739  1      CSO                 VENEZIA       238.0
# 3818    21a  5      VIA       LAGRANGE GIUSEPPE      5205.0
#
#                                              Ubicazione Tipo via_to_check  \
# 32                 CSO COMO N. 15 iNterNo club f. coNti               CSO
# 33                                                  CSO               CSO
# 210                         codvia 4386 N.008; (z.d. 4)            codvia
# 243               mm1 duomo codvia 9112 N.000; (z.d. 1)               mm1
# 651                  VIA SOLARI ANDREA N.002a; (z.d. 6)               VIA
# 744   VLE FORLANINI ENRICO coN iNgr. da p.zza artigi...               VLE
# 745               VLE FORLANINI ENRICO N.0505; (z.d. 4)               VLE
# 808             CSO GARIBALDI GIUSEPPE N.051a; (z.d. 1)               CSO
# 1203                     VLE TEODORICO N.0192; (z.d. 8)               VLE
# 1633              VIA GIOIA MELCHIORRE N.055a; (z.d. 2)               VIA
# 1775                    VIA MONTE ROSA N.019e; (z.d. 6)               VIA
# 2221                         VLE MONZA N.1773; (z.d. 2)               VLE
# 2223                          VLE MONZA N.353; (z.d. 2)               VLE
# 2413              PZA OBERDAN GUGLIELMO N.000; (z.d. 3)               PZA
# 2844  VIA LITTA MODIGNANI ALESSANDRO per rettifica t...               VIA
# 3042              VIA GNOCCHI DON CARLO N.033; (z.d. 7)               VIA
# 3114                       VLE ROMAGNA N.0562; (z.d. 3)               VLE
# 3275                    VIA CHIANCIANO N.0102; (z.d. 9)               VIA
# 3529  CSO GARIBALDI GIUSEPPE p.t. + semiNterrato N.0...               CSO
# 3534  CSO MAGENTA iNterNo piaNo rialzato N.083; (z.d...               CSO
# 3699  VIA PAGANO MARIO piaNo rialzato N.03739; (z.d. 1)               VIA
# 3818                      VLE SABOTINO N.021a; (z.d. 5)               VLE
#
#                                            Via_to_check
# 32                                                 COMO
# 33                                                 <NA>
# 210                                                4386
# 243                                   duomo codvia 9112
# 651                                       SOLARI ANDREA
# 744     FORLANINI ENRICO coN iNgr. da p.zza artigiaNato
# 745                                    FORLANINI ENRICO
# 808                                  GARIBALDI GIUSEPPE
# 1203                                          TEODORICO
# 1633                                   GIOIA MELCHIORRE
# 1775                                         MONTE ROSA
# 2221                                              MONZA
# 2223                                              MONZA
# 2413                                  OBERDAN GUGLIELMO
# 2844  LITTA MODIGNANI ALESSANDRO per rettifica topoN...
# 3042                                  GNOCCHI DON CARLO
# 3114                                            ROMAGNA
# 3275                                         CHIANCIANO
# 3529             GARIBALDI GIUSEPPE p.t. + semiNterrato
# 3534                     MAGENTA iNterNo piaNo rialzato
# 3699                        PAGANO MARIO piaNo rialzato
# 3818                                           SABOTINO

# %%
# Save in csv file all the types of Tipo Via
DATASET['Tipo via'].drop_duplicates().dropna().to_csv('tipo_via_types.csv', index=False)

# %%
# Check if the Tipo via_to_check is in the dataset of valid Tipo via types
valid_tipo_via = pd.read_csv('tipo_via_types.csv')['Tipo via'].tolist()

# Convert to string first to avoid pd.NA comparison issues
dfvia['Tipo via'] = dfvia['Tipo via'].astype(str).replace('<NA>', ' ').replace('nan', ' ')
dfvia['Tipo via_to_check'] = dfvia['Tipo via_to_check'].astype(str).replace('<NA>', ' ').replace('nan', ' ')

dfvia['Tipo via_to_check'] = dfvia['Tipo via_to_check'].apply(
    lambda x: x if x in valid_tipo_via else ' '
)

# Substitute Tipo via with Tipo via_to_check if they are different and Tipo via_to_check is not null
dfvia.loc[:, 'Tipo via'] = dfvia.apply(
    lambda row: row['Tipo via_to_check'] if row['Tipo via_to_check'] != ' ' and row['Tipo via'] != row['Tipo via_to_check'] else row['Tipo via'],
    axis=1
)

dfvia.iloc[check.index]
# Out:
#      Civico ZD Tipo via                     Via  Codice via  \
# 32       15  0      CSO                    <NA>         NaN
# 33        0  0      CSO                      15         9.0
# 210       8  4      CSO                    LODI      4068.0
# 243       0  1      CSO                SEMPIONE      7137.0
# 651      2a  6      VIA         FRATTINI PIETRO      5389.0
# 744     509  4      VLE                  MINCIO      4157.0
# 745     505  4      VLE             TAGLIAMENTO      4147.0
# 808     51a  1      CSO        CRISPI FRANCESCO      1063.0
# 1203    192  8      VLE       RUGGERO DI LAURIA      7163.0
# 1633    55a  2      VIA        QUATTRO NOVEMBRE      1199.0
# 1775    19e  6      VIA  BAZZI GIOVANNI ANTONIO      6102.0
# 2221   1773  2      VLE             OXILIA NINO      2287.0
# 2223    353  2      VLE                  PADOVA      2275.0
# 2413      0  3      PZA       MALPIGHI MARCELLO      2182.0
# 2844    99c  9      VIA            SAN GIUSEPPE      1442.0
# 3042     33  7      VIA   SAN MICHELE DEL CARSO      6212.0
# 3114    562  3      VLE         PACINI GIOVANNI      2571.0
# 3275    102  9      VIA        SUZZANI GIOVANNI      1446.0
# 3529   3032  1      CSO          CANONICA LUIGI      7121.0
# 3534     83  1      CSO       S. GIOV. SUL MURO       609.0
# 3699   3739  1      VIA                 VENEZIA       238.0
# 3818    21a  5      VLE       LAGRANGE GIUSEPPE      5205.0
#
#                                              Ubicazione Tipo via_to_check  \
# 32                 CSO COMO N. 15 iNterNo club f. coNti               CSO
# 33                                                  CSO               CSO
# 210                         codvia 4386 N.008; (z.d. 4)
# 243               mm1 duomo codvia 9112 N.000; (z.d. 1)
# 651                  VIA SOLARI ANDREA N.002a; (z.d. 6)               VIA
# 744   VLE FORLANINI ENRICO coN iNgr. da p.zza artigi...               VLE
# 745               VLE FORLANINI ENRICO N.0505; (z.d. 4)               VLE
# 808             CSO GARIBALDI GIUSEPPE N.051a; (z.d. 1)               CSO
# 1203                     VLE TEODORICO N.0192; (z.d. 8)               VLE
# 1633              VIA GIOIA MELCHIORRE N.055a; (z.d. 2)               VIA
# 1775                    VIA MONTE ROSA N.019e; (z.d. 6)               VIA
# 2221                         VLE MONZA N.1773; (z.d. 2)               VLE
# 2223                          VLE MONZA N.353; (z.d. 2)               VLE
# 2413              PZA OBERDAN GUGLIELMO N.000; (z.d. 3)               PZA
# 2844  VIA LITTA MODIGNANI ALESSANDRO per rettifica t...               VIA
# 3042              VIA GNOCCHI DON CARLO N.033; (z.d. 7)               VIA
# 3114                       VLE ROMAGNA N.0562; (z.d. 3)               VLE
# 3275                    VIA CHIANCIANO N.0102; (z.d. 9)               VIA
# 3529  CSO GARIBALDI GIUSEPPE p.t. + semiNterrato N.0...               CSO
# 3534  CSO MAGENTA iNterNo piaNo rialzato N.083; (z.d...               CSO
# 3699  VIA PAGANO MARIO piaNo rialzato N.03739; (z.d. 1)               VIA
# 3818                      VLE SABOTINO N.021a; (z.d. 5)               VLE
#
#                                            Via_to_check
# 32                                                 COMO
# 33                                                 <NA>
# 210                                                4386
# 243                                   duomo codvia 9112
# 651                                       SOLARI ANDREA
# 744     FORLANINI ENRICO coN iNgr. da p.zza artigiaNato
# 745                                    FORLANINI ENRICO
# 808                                  GARIBALDI GIUSEPPE
# 1203                                          TEODORICO
# 1633                                   GIOIA MELCHIORRE
# 1775                                         MONTE ROSA
# 2221                                              MONZA
# 2223                                              MONZA
# 2413                                  OBERDAN GUGLIELMO
# 2844  LITTA MODIGNANI ALESSANDRO per rettifica topoN...
# 3042                                  GNOCCHI DON CARLO
# 3114                                            ROMAGNA
# 3275                                         CHIANCIANO
# 3529             GARIBALDI GIUSEPPE p.t. + semiNterrato
# 3534                     MAGENTA iNterNo piaNo rialzato
# 3699                        PAGANO MARIO piaNo rialzato
# 3818                                           SABOTINO

# %%
condition = (
    (dfvia['Tipo via'].fillna(' ') != dfvia['Tipo via_to_check'].fillna(' ')) 
)
check = dfvia[condition]
check
# Out:
#     Civico ZD Tipo via       Via  Codice via  \
# 210      8  4      CSO      LODI      4068.0
# 243      0  1      CSO  SEMPIONE      7137.0
#
#                                 Ubicazione Tipo via_to_check  \
# 210            codvia 4386 N.008; (z.d. 4)
# 243  mm1 duomo codvia 9112 N.000; (z.d. 1)
#
#           Via_to_check
# 210               4386
# 243  duomo codvia 9112

# %% [markdown]
# ### Via

# %%
dfvia = dfvia.drop(['Civico', 'ZD'], axis=1)

# Take the part in Via_to_check before the first minuscule letter or number
dfvia['Via_to_check'] = dfvia['Via_to_check'].str.split(r'[a-z0-9]', n=1).str[0].str.strip()
dfvia['Via'] = dfvia['Via'].astype(str).replace('<NA>', ' ').replace('nan', ' ').str.strip()
dfvia['Via_to_check'] = dfvia['Via_to_check'].astype(str).replace('<NA>', ' ').replace('nan', ' ').str.strip()

condition = (
    (dfvia['Via'].fillna(' ') != dfvia['Via_to_check'].fillna(' ')) 
)
check = dfvia[condition]
check
# Out:
#      Tipo via                Via  Codice via  \
# 32        CSO                            NaN
# 33        CSO                 15         9.0
# 210       CSO               LODI      4068.0
# 243       CSO           SEMPIONE      7137.0
# 319       VIA         FERMIGNANO      1607.0
# ...       ...                ...         ...
# 3699      VIA            VENEZIA       238.0
# 3713      VIA   GROSSICH ANTONIO      2576.0
# 3764      VIA             MINCIO      4157.0
# 3767      VIA        LORENTEGGIO      5132.0
# 3818      VLE  LAGRANGE GIUSEPPE      5205.0
#
#                                              Ubicazione Tipo via_to_check  \
# 32                 CSO COMO N. 15 iNterNo club f. coNti               CSO
# 33                                                  CSO               CSO
# 210                         codvia 4386 N.008; (z.d. 4)
# 243               mm1 duomo codvia 9112 N.000; (z.d. 1)
# 319                       VIA BOVISASCA N.173; (z.d. 9)               VIA
# ...                                                 ...               ...
# 3699  VIA PAGANO MARIO piaNo rialzato N.03739; (z.d. 1)               VIA
# 3713                 VIA PILO ROSOLINO N.019b; (z.d. 3)               VIA
# 3764             VIA SERLIO SEBASTIANO N.0082; (z.d. 4)               VIA
# 3767                  VIA SOLARI ANDREA N.043; (z.d. 6)               VIA
# 3818                      VLE SABOTINO N.021a; (z.d. 5)               VLE
#
#            Via_to_check
# 32                 COMO
# 33
# 210
# 243
# 319           BOVISASCA
# ...                 ...
# 3699       PAGANO MARIO
# 3713      PILO ROSOLINO
# 3764  SERLIO SEBASTIANO
# 3767      SOLARI ANDREA
# 3818           SABOTINO
#
# [76 rows x 6 columns]

# %%
# Substitute Via with Via_to_check if they are different and Via_to_check is not empty
dfvia.loc[:, 'Via'] = dfvia.apply(
    lambda row: row['Via_to_check'].strip() if row['Via_to_check'].strip() != '' and row['Via'].strip() != row['Via_to_check'].strip() else row['Via'].strip(),
    axis=1
)

dfvia.iloc[check.index]
# Out:
#      Tipo via                Via  Codice via  \
# 32        CSO               COMO         NaN
# 33        CSO                 15         9.0
# 210       CSO               LODI      4068.0
# 243       CSO           SEMPIONE      7137.0
# 319       VIA          BOVISASCA      1607.0
# ...       ...                ...         ...
# 3699      VIA       PAGANO MARIO       238.0
# 3713      VIA      PILO ROSOLINO      2576.0
# 3764      VIA  SERLIO SEBASTIANO      4157.0
# 3767      VIA      SOLARI ANDREA      5132.0
# 3818      VLE           SABOTINO      5205.0
#
#                                              Ubicazione Tipo via_to_check  \
# 32                 CSO COMO N. 15 iNterNo club f. coNti               CSO
# 33                                                  CSO               CSO
# 210                         codvia 4386 N.008; (z.d. 4)
# 243               mm1 duomo codvia 9112 N.000; (z.d. 1)
# 319                       VIA BOVISASCA N.173; (z.d. 9)               VIA
# ...                                                 ...               ...
# 3699  VIA PAGANO MARIO piaNo rialzato N.03739; (z.d. 1)               VIA
# 3713                 VIA PILO ROSOLINO N.019b; (z.d. 3)               VIA
# 3764             VIA SERLIO SEBASTIANO N.0082; (z.d. 4)               VIA
# 3767                  VIA SOLARI ANDREA N.043; (z.d. 6)               VIA
# 3818                      VLE SABOTINO N.021a; (z.d. 5)               VLE
#
#            Via_to_check
# 32                 COMO
# 33
# 210
# 243
# 319           BOVISASCA
# ...                 ...
# 3699       PAGANO MARIO
# 3713      PILO ROSOLINO
# 3764  SERLIO SEBASTIANO
# 3767      SOLARI ANDREA
# 3818           SABOTINO
#
# [76 rows x 6 columns]

# %%
condition = (
    (dfvia['Via'].fillna(' ') != dfvia['Via_to_check'].fillna(' ')) 
)
check = dfvia[condition]
check
# Out:
#     Tipo via       Via  Codice via                             Ubicazione  \
# 33       CSO        15         9.0                                    CSO
# 210      CSO      LODI      4068.0            codvia 4386 N.008; (z.d. 4)
# 243      CSO  SEMPIONE      7137.0  mm1 duomo codvia 9112 N.000; (z.d. 1)
#
#     Tipo via_to_check Via_to_check
# 33                CSO
# 210
# 243

# %% [markdown]
# ### Codice via

# %%
# Save in csv file all the different Via with their corrispective codice via, without duplicates
# Also save the number of times each row appears
pre = DATASET[['Tipo via', 'Via', 'Codice via']].copy()
pre['count'] = pre.groupby(['Tipo via', 'Via', 'Codice via'])['Tipo via'].transform('count')
pre = pre.drop_duplicates()
pre = pre.sort_values(by=['Tipo via', 'Via'])
pre.to_csv('codice_via_mapping_pre.csv', index=False)

# %%
# Show rows where the same Tipo via + Via combination has multiple different Codice via values
duplicated_mask = pre.duplicated(subset=['Tipo via', 'Via'], keep=False)
pre[duplicated_mask].sort_values(by=['Tipo via', 'Via', 'Codice via']).to_csv('duplicated_tipo_via_via.csv', index=False)

# Save the mapping of (Tipo via, Via) that are new and not in the pre dataset
not_in_pre = dfvia[['Tipo via', 'Via', 'Codice via']].copy()
not_in_pre['count'] = not_in_pre.groupby(['Tipo via', 'Via', 'Codice via'])['Tipo via'].transform('count')
not_in_pre = not_in_pre.drop_duplicates()
not_in_pre = not_in_pre[~not_in_pre.set_index(['Tipo via', 'Via']).index.isin(pre.set_index(['Tipo via', 'Via']).index)]
not_in_pre = not_in_pre.sort_values(by=['Tipo via', 'Via'])
not_in_pre.to_csv('codice_via_mapping_not_in_pre.csv', index=False)
not_in_pre
# Out:
#      Tipo via                     Via  Codice via  count
# 33        CSO                      15         9.0    1.0
# 319       VIA               BOVISASCA      1607.0    1.0
# 3586      VIA               BOVISASCA      1109.0    1.0
# 1438      VIA                 CALDERA      6194.0    1.0
# 2490      VIA  CICERONE  MARCO TULLIO      1294.0    1.0
# 3311      VIA             F.LLI GABBA       314.0    1.0
# 1161      VIA       GNOCCHI DON CARLO      6100.0    1.0
# 3042      VIA       GNOCCHI DON CARLO      6212.0    1.0
# 1693      VIA               LONGARONE      7241.0    1.0
# 2845      VIA               LONGARONE      7292.0    1.0
# 3673      VIA          MASSENA ANDREA      7462.0    1.0
# 3009      VIA             PANTELLERIA      7461.0    1.0
# 2873      VIA         SANT' ELEMBARDO      2356.0    1.0
# 2061      VIA                TOLMEZZO      2650.0    1.0
# 2732      VIA                TOLMEZZO      2659.0    1.0
# 744       VLE        FORLANINI ENRICO      4157.0    1.0
# 745       VLE        FORLANINI ENRICO      4147.0    1.0

# %% [markdown]
# Capire cosa fare per i codice via che hanno due valori diversi singoli e per quelli che non hanno un codice via iniziale

# %% [markdown]
# L'altro progetto non fa come noi, ma mantiene le vie iniziali. Quindi o ritorniamo indietro e lasciamo le vie come erano (anche diverse da quelle nella colonna ubicazione), oppure possiamo dire: abbiamo delle nuove vie, gli assegniamo un nuovo codice via

# %% [markdown]
# DA CONTROLLARE RIGA SEMPIONE (quella con mm1)

# %% [markdown]
# ##### Esempio

# %%
# For the new rows in not_in_pre, we generate new Codice via values starting from the maximum existing Codice via in pre
# If there are more item with the same Tipo via and Via, they will get the same new Codice via
max_codice_via = pre['Codice via'].max()
new_codice_via = max_codice_via + 1
codice_via_mapping = {}
for index, row in not_in_pre.iterrows():
    key = (row['Tipo via'], row['Via'])
    if key not in codice_via_mapping:
        codice_via_mapping[key] = new_codice_via
        new_codice_via += 1
# Assign new Codice via to not_in_pre
not_in_pre['Codice via'] = not_in_pre.apply(lambda row: codice_via_mapping[(row['Tipo via'], row['Via'])], axis=1)
not_in_pre
# Out:
#      Tipo via                     Via  Codice via  count
# 33        CSO                      15      7549.0    1.0
# 319       VIA               BOVISASCA      7550.0    1.0
# 3586      VIA               BOVISASCA      7550.0    1.0
# 1438      VIA                 CALDERA      7551.0    1.0
# 2490      VIA  CICERONE  MARCO TULLIO      7552.0    1.0
# 3311      VIA             F.LLI GABBA      7553.0    1.0
# 1161      VIA       GNOCCHI DON CARLO      7554.0    1.0
# 3042      VIA       GNOCCHI DON CARLO      7554.0    1.0
# 1693      VIA               LONGARONE      7555.0    1.0
# 2845      VIA               LONGARONE      7555.0    1.0
# 3673      VIA          MASSENA ANDREA      7556.0    1.0
# 3009      VIA             PANTELLERIA      7557.0    1.0
# 2873      VIA         SANT' ELEMBARDO      7558.0    1.0
# 2061      VIA                TOLMEZZO      7559.0    1.0
# 2732      VIA                TOLMEZZO      7559.0    1.0
# 744       VLE        FORLANINI ENRICO      7560.0    1.0
# 745       VLE        FORLANINI ENRICO      7560.0    1.0

# %% [markdown]
# ### Test

# %%
# Join all together
final = DATASET.copy()
# First, update DATASET with the modified Tipo via and Via from dfvia
final['Tipo via'] = dfvia['Tipo via']
final['Via'] = dfvia['Via']

# Create a mapping from not_in_pre with new Codice via values
not_in_pre_mapping = not_in_pre.set_index(['Tipo via', 'Via'])['Codice via'].to_dict()

# Update Codice via in final for rows that match not_in_pre
final['Codice via'] = final.apply(
    lambda row: not_in_pre_mapping.get((row['Tipo via'], row['Via']), row['Codice via']),
    axis=1
)

# For rows in final where Codice via is null, check if there's a match in pre and assign it
pre_mapping = pre.set_index(['Tipo via', 'Via'])['Codice via'].to_dict()
for index, row in final[final['Codice via'].isnull()].iterrows():
    key = (row['Tipo via'], row['Via'])
    if key in pre_mapping:
        final.at[index, 'Codice via'] = pre_mapping[key]

final
# Out:
#      Civico ZD Tipo via                Via  Codice via  \
# 0        10  6      LGO      DEI GELSOMINI      5394.0
# 1         3  9      PZA              FIDIA      1144.0
# 2        10  5      VIA              ADIGE      4216.0
# 3         9  1      VIA  BARACCHINI FLAVIO       356.0
# 4        12  4      VIA            BERGAMO      3189.0
# ...     ... ..      ...                ...         ...
# 3904      1  1      VIA   SARPI FRA' PAOLO      7210.0
# 3905      4  1      CSO  DI PORTA TICINESE       541.0
# 3906      2  9      VIA          CANDOGLIA      1518.0
# 3907     2a  1      VIA             NIRONE       640.0
# 3908     15  1      VIA          MADONNINA       134.0
#
#                                              Ubicazione Civico_to_check  \
# 0                      LGO DEI GELSOMINI N. 10 (z.d. 6)              10
# 1                               PZA FIDIA N. 3 (z.d. 9)               3
# 2                              VIA ADIGE N. 10 (z.d. 5)              10
# 3                   VIA BARACCHINI FLAVIO N. 9 (z.d. 1)               9
# 4                            VIA BERGAMO N. 12 (z.d. 4)              12
# ...                                                 ...             ...
# 3904  VIA SARPI FRA' PAOLO N. 1 coN iNgr.da v.le moN...               1
# 3905              CSO DI PORTA TICINESE N. 4 ; (z.d. 1)               4
# 3906                      VIA CANDOGLIA N. 2 ; (z.d. 9)               2
# 3907                        VIA NIRONE N.002a; (z.d. 1)              2a
# 3908                     VIA MADONNINA N. 15 ; (z.d. 1)              15
#
#      ZD_to_check Tipo via_to_check       Via_to_check  \
# 0              6               LGO      DEI GELSOMINI
# 1              9               PZA              FIDIA
# 2              5               VIA              ADIGE
# 3              1               VIA  BARACCHINI FLAVIO
# 4              4               VIA            BERGAMO
# ...          ...               ...                ...
# 3904           1               VIA   SARPI FRA' PAOLO
# 3905           1               CSO  DI PORTA TICINESE
# 3906           9               VIA          CANDOGLIA
# 3907           1               VIA             NIRONE
# 3908           1               VIA          MADONNINA
#
#                   Civico_additional ZD_additional
# 0                              <NA>          <NA>
# 1                              <NA>          <NA>
# 2                              <NA>          <NA>
# 3                              <NA>          <NA>
# 4                              <NA>          <NA>
# ...                             ...           ...
# 3904  coN iNgr.da v.le moNtello 4/6          <NA>
# 3905                           <NA>          <NA>
# 3906                           <NA>          <NA>
# 3907                           <NA>          <NA>
# 3908                           <NA>          <NA>
#
# [3909 rows x 12 columns]
